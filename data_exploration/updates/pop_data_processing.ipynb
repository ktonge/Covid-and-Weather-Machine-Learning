# %%
# Dependencies 
import pandas as pd
import numpy as np

# %%
# File to load 
census_df = pd.read_csv ("census_pop_density.csv")

# %%
import unicodedata
currentFile = open("NCHS.csv", "rt",encoding="utf-8")

# %%
NCHS_df = pd.read_csv (currentFile)

# %%
# Cleaning Census Data
census_df.head()
for col in census_df.columns:
    print(col)
# Out:
# OBJECTID
# COUNTYNS
# GEOID
# ALAND
# AWATER
# NAME
# State
# B25010_001E
# B25010_001M
# B25010_002E
# B25010_002M
# B25010_003E
# B25010_003M
# B01001_001E
# B01001_001M
# B01001_calc_PopDensity
# created_user
# created_date
# last_edited_user
# last_edited_date
# B01001_calc_PopDensityM
# SHAPE_Length
# SHAPE_Area

# %%
census_df=census_df.drop(columns=["GEOID","OBJECTID", "COUNTYNS", "ALAND", "AWATER","B25010_002E",
"B25010_002M", "B25010_003E", "B25010_003M","B01001_001M", "created_user", "created_date",
"last_edited_user", "last_edited_date", "B01001_calc_PopDensityM", "SHAPE_Length","SHAPE_Area","B25010_001M"])

# %%
census_df=census_df.rename(columns={"NAME": "county","State":"state","B25010_001E":"avg_household","B01001_calc_PopDensity":"pop_dens(/sqmi)","B01001_001E":"total_pop" })
census_df.head()
census_df= census_df.drop_duplicates()

# %%
# Cleaning NHCS Data
NCHS_df.head()
# Out:
#    FIPS code State Abr.     County name County 2012 pop  2013 code  2006 code  \
# 0       1001         AL  Autauga County           55514          3          3
# 1       1003         AL  Baldwin County          190790          4          5
# 2       1005         AL  Barbour County           27201          6          5
# 3       1007         AL     Bibb County           22597          2          2
# 4       1009         AL   Blount County           57826          2          2
#
#   1990-based code
# 0               3
# 1               3
# 2               5
# 3               6
# 4               3

# %%
NCHS_df=NCHS_df.drop(columns={"County 2012 pop","2006 code", "1990-based code","FIPS code","State Abr."})

# %%
NCHS_df.head()
# Out:
#       County name  2013 code
# 0  Autauga County          3
# 1  Baldwin County          4
# 2  Barbour County          6
# 3     Bibb County          2
# 4   Blount County          2

# %%
NCHS_df=NCHS_df.rename(columns={"County name":"county","2013 code":"nchs_code_2013"})
NCHS_df= NCHS_df.drop_duplicates("county")

# %%
# Combining the dataframes
county_pop_df=pd.merge(census_df,NCHS_df,how="inner",on=["county"])

# %%
county_pop_df.head()
# Out:
#            county          state  avg_household  total_pop  pop_dens(/sqmi)  \
# 0  Autauga County        Alabama           2.59      55200        35.853419
# 1  Baldwin County        Alabama           2.61     208107        50.541504
# 2  Baldwin County        Georgia           2.54      45286        67.588266
# 3  Barbour County        Alabama           2.49      25782        11.247981
# 4  Barbour County  West Virginia           2.52      16730        18.939514
#
#    nchs_code_2013
# 0               3
# 1               4
# 2               4
# 3               6
# 4               6

# %%
county_pop_df=county_pop_df.loc[(county_pop_df["nchs_code_2013"]<=2)&(county_pop_df["pop_dens(/sqmi)"]>1000)]
county_pop_df=county_pop_df.drop_duplicates(ignore_index=True)
county_pop_df.head(10)
# Out:
#                  county                 state  avg_household  total_pop  \
# 0         Orange County            California           3.02    3164182
# 1  San Francisco County            California           2.36     870044
# 2         Denver County              Colorado           2.31     693417
# 3      Middlesex County            New Jersey           2.80     826698
# 4  District of Columbia  District of Columbia           2.29     684498
# 5         Nassau County              New York           3.00    1356564
# 6       Pinellas County               Florida           2.31     957875
# 7         DuPage County              Illinois           2.69     931743
# 8        Baltimore city              Maryland           2.48     614700
# 9          Essex County            New Jersey           2.73     793555
#
#    pop_dens(/sqmi)  nchs_code_2013
# 0      1541.026670               1
# 1      7168.190471               1
# 2      1746.533667               1
# 3      1032.248366               2
# 4      4322.952569               1
# 5      1840.443984               2
# 6      1351.009895               1
# 7      1097.706801               2
# 8      2932.040761               1
# 9      2430.062385               2

# %%
county_pop_df.dropna(inplace = True)

# %%
county_pop_df['county'] = county_pop_df['county'].str.rsplit(" ", n = 1, expand=True)[0]
county_pop_df.head()
# Out:
#           county                 state  avg_household  total_pop  \
# 0         Orange            California           3.02    3164182
# 1  San Francisco            California           2.36     870044
# 2         Denver              Colorado           2.31     693417
# 3      Middlesex            New Jersey           2.80     826698
# 4    District of  District of Columbia           2.29     684498
#
#    pop_dens(/sqmi)  nchs_code_2013
# 0      1541.026670               1
# 1      7168.190471               1
# 2      1746.533667               1
# 3      1032.248366               2
# 4      4322.952569               1

# %%
county_pop_df['county']=county_pop_df['county'].apply(str.lower)
county_pop_df['state']=county_pop_df['state'].apply(str.lower)

# %%
county_pop_df.to_csv('county_pop_final.csv',header=True, index=True)

# %%
dense_county_pop_df=county_pop_df.loc[(county_pop_df["pop_dens(/sqmi)"]>=3000)]
sparse_county_pop_df=county_pop_df.loc[(county_pop_df["pop_dens(/sqmi)"]<=2999)]

# %%
dense_county_pop_df.to_csv('dense_county_pop.csv',header=True, index=True)
sparse_county_pop_df.to_csv('sparse_county_pop.csv',header=True, index=True)
